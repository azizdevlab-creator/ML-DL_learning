# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3, 4], index = ['a', 'b', 'c', 'd'])
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
df = pd.DataFrame({"name": ['John', 'Doe', 'Karl'], 
                  "Age": [5, 6, None]}, index = ['one', 'two', 'three'])
print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        name  Age
# one    John  5.0
# two     Doe  6.0
# three  Karl  NaN

# %%
# pd.read_csv('file.csv')
# pd.read_excel('file.xlsx')
# pd.read_json('file.json')

# df.to_csv('save.csv', index = False)
# df.to_excel('save.xlsx')

# %%
df.head(1)
# Out:
#    name  Age
# 0  John    5

# %%
df.tail(1)
# Out:
#   name  Age
# 1  Doe    6

# %%
df.shape
# Out:
# (2, 2)

# %%
df.describe()
# Out:
#             Age
# count  2.000000
# mean   5.500000
# std    0.707107
# min    5.000000
# 25%    5.250000
# 50%    5.500000
# 75%    5.750000
# max    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    2 non-null      object
#  1   Age     2 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 164.0+ bytes

# %%
df.dtypes
# Out:
# name    object
# Age      int64
# dtype: object

# %%
df.columns
# Out:
# Index(['name', 'Age'], dtype='object')

# %%
df['Age']
# Out:
# 0    5
# 1    6
# Name: Age, dtype: int64

# %%
df[['Age', 'name']]
# Out:
#    Age  name
# 0    5  John
# 1    6   Doe

# %%
df.iloc[0]
# Out:
# name    John
# Age        5
# Name: one, dtype: object

# %%
df.loc['one']
# Out:
# name    John
# Age        5
# Name: one, dtype: object

# %%
df.iloc[0:2]
# Out:
#      name  Age
# one  John    5
# two   Doe    6

# %%
df[df['Age'] > 5]
# Out:
#     name  Age
# two  Doe    6

# %%
df.isnull()
# Out:
#         name    Age
# one    False  False
# two    False  False
# three  False   True

# %%
df.dropna()
# Out:
#      name  Age
# one  John  5.0
# two   Doe  6.0

# %%
df.fillna(7)
# Out:
#        name  Age
# one    John  5.0
# two     Doe  6.0
# three  Karl  7.0
